# %% [markdown]
# <h1 align="center">Урок 4. Предел функции. Часть 1</h1>

# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Тема “Предел функции”

# %% [markdown]
# 1. Предложить пример функции, не имеющей предела в нуле и в бесконечностях.

# %% [markdown]
# $$ f(x) = tg(x+\frac{1}{x}) $$

# %%
sns.set(rc={'figure.figsize': (18, 12)})

x = np.arange(-50, 50, 0.5)
y = np.tan(x+1/x)

sns.set_style("whitegrid", {"grid.color": "grey"})
plt.axhline(linewidth=1, color="black")
plt.axvline(linewidth=1, color="black")
plt.plot(x,y, color="red")
plt.show()

# %% [markdown]
# 2. Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %% [markdown]
# $$ f(x) = sign(x) $$

# %% [markdown]
# 3. Исследовать функцию f(x) = x<sup>3</sup> - x<sup>2</sup> по плану

# %%
x = np.linspace(-2, 3, 31)
y = x**3 - x**2
fig = plt.figure()

plt.axis("equal")
plt.plot(x, y, color="red")

# %% [markdown]
# 3.1 Область задания и область значений.

# %% [markdown]
# D(f) ∈ (-∞;+∞) <br/>
# E(f) ∈ (-∞;+∞)

# %% [markdown]
# 3.2 Нули функции и их кратность.

# %% [markdown]
# $$x^3 - x^2=0$$
#
# $$x^2 * (x - 1)=0$$

# %% [markdown]
# x = 0 - корень кратности 2<br />
# x = 1 - корень кратности 1

# %% [markdown]
# 3.3 Отрезки знакопостоянства.

# %% [markdown]
# $$ f(x) < 0\ Ɐx∈ (-∞; 0) ∪ (0;1)$$
#
# Для примера: $$ f(-5) = (-5)^3-(-5)^2= -150$$
# $$ f(0.1) = (0.1)^3-(0.1)^2= -0.009$$
# <br />
# $$ f(x) > 0\ Ɐx∈ (1; +∞)$$
#
# Для примера: $$ f(5) = 5^3-5^2= 100$$

# %% [markdown]
# 3.4 Интервалы монотонности.

# %% [markdown]
# Найдём корни первой производной:

# %% [markdown]
# $$ f'(x) = 0$$
#
# $$ 3x^2 - 2x = 0$$
#
# $$ x(3x - 2) = 0$$
#
# $$x = 0, x = \frac{2}{3}$$
#
# $$f(x)\ возрастает\ при\ x∈ (-∞; 0) ∪ (\frac{2}{3};+∞)$$
#
# $$f(x)\ убывает\ при\ x∈ (0; \frac{2}{3})$$

# %% [markdown]
# 3.5 Четность функции.

# %% [markdown]
# Функция общего вида

# %% [markdown]
# 3.6 Ограниченность.

# %% [markdown]
# Не ограничена

# %% [markdown]
# 3.7 Периодичность.

# %% [markdown]
# Не является периодической

# %% [markdown]
# 4. Найти предел:

# %% [markdown]
# 4.1 $$\lim_{x\to0} \frac{3x^3 - 2x^2}{4x^2} = \bigl(\frac{0}{0}\bigr) = \lim_{x\to0} (\frac{3}{4}x - 0.5) = -0.5$$

# %% [markdown]
# 4.2 $$\lim_{x\to0} \frac{\sqrt{1+x} - 1}{\sqrt[3]{1+x} - 1} = \bigl(\frac{0}{0}\bigr) = \lim_{x\to0} \frac{\sqrt{1+x} - 1}{\sqrt[3]{1+x} - 1} * \frac{\sqrt{1+x}+1}{\sqrt{1+x}+1} * \frac{\sqrt[3]{(1+x)^2}+\sqrt[3]{1+x}+1}{\sqrt[3]{(1+x)^2}+\sqrt[3]{1+x}+1} = \lim_{x\to0} \frac{1+x-1}{1+x-1} * \frac{\sqrt[3]{(1+x)^2}+\sqrt[3]{1+x}+1}{\sqrt{1+x}+1} = 1.5$$

# %% [markdown]
# ### Тема “Теоремы о пределах”

# %% [markdown]
# 1. Найти предел:

# %% [markdown]
# 1.1 $$\lim_{x \to 0} \frac{sin(2x)}{4x} = \bigl(\frac{0}{0}\bigr) = \lim_{x \to 0} \frac{sin(2x)}{2*2x} = 0.5$$

# %% [markdown]
# 1.2 $$\lim_{x \to 0} \frac{x}{sin(x)} = \bigl(\frac{0}{0}\bigr) = 1, -\ следствие\ из\ первого\ замечательного\ предела$$
