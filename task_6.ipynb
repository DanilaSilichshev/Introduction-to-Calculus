# %% [markdown]
# <h1 align="center">Урок 7. Производная функции одной переменной. Часть 2</h1>

# %% [markdown]
# ### Тема “Понятие о производной”

# %% [markdown]
# 1. Найти длину x и ширину y прямоугольника при заданном периметре P = 144cм,<br> при которых данный прямоугольник имеет наибольшую площадь S.

# %% [markdown]
# Представлена задача оптимизации
# $$ S' = (xy)' = 0$$
#
# Выразим y через x
#
# $$2(x+y) = 144,\ => x+y=72,\ => y = 72 - x$$
#
# Подставим и определим значения x и y
#
# $$ (x(72-x))' = 0$$
#
# $$ (72x-x^2)' = 0$$
#
# $$ 72-2x = 0$$
#
# $$ {x=36,\ y = 36}$$

# %% [markdown]
# 2. Найти экстремумы функций, если они есть:

# %% [markdown]
# a. $$y = |2x|$$
#
# $$ Экстремум\ \exists\ при\ x_{min} = 0 $$

# %% [markdown]
# b. $$y = x^3$$
#
# $$y' = 3x^2$$
#
# $$Производная\ чётной\ степени,\ экстремумов\ нет$$

# %% [markdown]
# c. $$y=e^{3x}$$
#
# $$y'=3e^{3x}$$
#
# $$Экстремумов\ нет$$

# %%
import numpy as np
import math

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

sns.set(rc={'figure.figsize': (18, 12)})

x = np.arange(-1.5, 1.5, 0.05)
y = 3*np.array(list(map(math.exp, 3*x)))

sns.set_style("whitegrid", {"grid.color": "grey"})
plt.axhline(linewidth=1, color="black")
plt.axvline(linewidth=1, color="black")
plt.plot(x,y, color="red")
plt.show()

# %% [markdown]
# d. $$y = x^3-5x$$
#
# $$y' = 3x^2 - 5$$
#
# $$Производная\ чётной\ степени,\ экстремумов\ нет$$
